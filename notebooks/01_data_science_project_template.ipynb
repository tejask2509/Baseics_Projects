# %% [markdown]
# # Project title
#
# **Question:** What decision should this analysis help someone make?
#
# **Owner:** Your name  |  **Date:** YYYY-MM-DD  |  **Status:** Draft
#
# This notebook is designed to be readable from top to bottom. Keep the narrative, assumptions, and decisions close to the code that supports them.

# %% [markdown]
# ## 1. Define the problem
#
# - **Context:** Why does this question matter?
# - **Success metric:** How will we know the analysis is useful?
# - **Scope:** What is included and excluded?
# - **Limitations:** What could make the result misleading?

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(exist_ok=True)

pd.set_option("display.max_columns", 100)
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 2. Load and validate data
#
# Replace the example loader with a project-specific path. Keep data files local unless you have permission to publish them.

# %%
# Example:
# data = pd.read_csv(DATA_DIR / "clean_dataset.csv")
# display(data.head())
# print(data.shape)
# display(data.dtypes)
# display(data.isna().mean().sort_values(ascending=False).head(10))

# %% [markdown]
# ## 3. Explore
#
# State what each chart tests. Avoid making a chart merely because the column exists.

# %%
# Example chart:
# fig, ax = plt.subplots(figsize=(8, 5))
# sns.histplot(data=data, x="measure", kde=True, ax=ax)
# ax.set(title="Distribution of the measure", xlabel="Measure", ylabel="Count")
# fig.tight_layout()
# fig.savefig(OUTPUT_DIR / "measure-distribution.png", dpi=160, bbox_inches="tight")

# %% [markdown]
# ## 4. Analyze or model
#
# Document the method, the baseline, and why the method fits the question. Report uncertainty where it matters.

# %% [markdown]
# ## 5. Findings and next steps
#
# ### Findings
#
# 1. Finding supported by evidence.
# 2. Finding supported by evidence.
#
# ### Recommendation
#
# What should the reader do differently because of this analysis?
#
# ### Caveats
#
# What should not be concluded from this work?
